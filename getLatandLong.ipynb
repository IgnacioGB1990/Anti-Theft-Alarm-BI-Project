# %% [markdown]
# ### Get Latitute and Longitud from Dataframe

# %%
import pandas as pd
import time
import random

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from IPython.display import display
from datetime import datetime


# 1. Abre navegador en blanco
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# 2. Abrimos web mercadona
url ="https://www.latlong.net/convert-address-to-lat-long.html"
driver.get(url)

# Esperamos unos segundillos
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/j0/w6j4gtqn3qgbyxvxzx172r_m0000gn/T/ipykernel_53269/148668270.py in <module>
#      14
#      15 # 1. Abre navegador en blanco
# ---> 16 service = Service(ChromeDriverManager().install())
#      17 driver = webdriver.Chrome(service=service)
#      18
#
# ~/opt/anaconda3/lib/python3.9/site-packages/webdriver_manager/chrome.py in install(self)
#      37
#      38     def install(self) -> str:
# ---> 39         driver_path = self._get_driver_path(self.driver)
#      40         os.chmod(driver_path, 0o755)
#      41         return driver_path
#
# ~/opt/anaconda3/lib/python3.9/site-packages/webdriver_manager/core/manager.py in _get_driver_path(self, driver)
#      28             return binary_path
#      29
# ---> 30         file = self._download_manager.download_file(driver.get_url())
#      31         binary_path = self.driver_cache.save_file_to_cache(driver, file)
#      32         return binary_path
#
# ~/opt/anaconda3/lib/python3.9/site-packages/webdriver_manager/core/download_manager.py in download_file(self, url)
#      26     def download_file(self, url: str) -> File:
#      27         log(f"About to download new driver from {url}")
# ---> 28         response = self._http_client.get(url)
#      29         return File(response)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/webdriver_manager/core/http.py in get(self, url, **kwargs)
#      31     def get(self, url, **kwargs) -> Response:
#      32         resp = requests.get(url=url, verify=self._ssl_verify, stream=True, **kwargs)
# ---> 33         self.validate_response(resp)
#      34         if wdm_progress_bar():
#      35             show_download_progress(resp)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/webdriver_manager/core/http.py in validate_response(resp)
#      14         status_code = resp.status_code
#      15         if status_code == 404:
# ---> 16             raise ValueError(f"There is no such driver by url {resp.url}")
#      17         elif status_code == 401:
#      18             raise ValueError(f"API Rate limit exceeded. You have to add GH_TOKEN!!!")
#
# ValueError: There is no such driver by url https://chromedriver.storage.googleapis.com/117.0.5938/chromedriver_mac64.zip

# %% [markdown]
# # Aceptamos cookies
# cookies = driver.find_element(By.CLASS_NAME,"ui-button.ui-button--small.ui-button--primary.ui-button--positive")
# cookies.send_keys(Keys.ENTER)
#
# # Buscamos por clase el campo de input para poder introducir nuestro código postal
# input = driver.find_element(By.CLASS_NAME,"ym-hide-content")
#
# # Introducimos el código postal
# input.send_keys("28016")
#
# # Esperamos unos segundillos
# time.sleep(round(random.uniform(0.5,3),1))
#
# # Le damos a ENTER
# input.send_keys(Keys.ENTER)   #driver.find_element_by_id("submit").click()

# %%
# !brew install --cask chromedriver
# Out:
# Running `brew update --auto-update`...
# ==> Homebrew collects anonymous analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics have been recorded yet (nor will be during this `brew` run).
#
# ==> You have set:
#   HOMEBREW_NO_INSTALL_FROM_API
# but we have dramatically sped up and fixed many bugs in the way we do Homebrew updates since.
# Please consider unsetting these and tweaking the values based on the new behaviour.
#
#
# ==> Auto-updated Homebrew!
# Updated 2 taps (heroku/brew and homebrew/core).
# ==> New Formulae
# adb-enhanced                             lr
# aerleon                                  ls-lint
# alass                                    lune
# ansible@7                                lxi-tools
# apify-cli                                mailpit
# apko                                     mariadb@10.11
# apprise                                  mariadb@11.0
# argparse                                 massdriver
# arm-none-eabi-binutils                   medusa
# arm-none-eabi-gcc                        melange
# arm-none-eabi-gdb                        meson-python
# asn                                      mfem
# asnmap                                   mgis
# ast-grep                                 minigraph
# aws-amplify                              mjml
# bacon                                    mods
# bashate                                  modsecurity
# bazel-diff                               mtbl
# bazel-remote                             mvfst
# bbot                                     mvt
# bfs                                      mysql-client@8.0
# bilix                                    mysql@8.0
# biome                                    neonctl
# blades                                   nerdfix
# blake3                                   nexttrace
# blink                                    notation
# boolector                                ntbtls
# botan@2                                  numbat
# caracal                                  ollama
# cargo-all-features                       openfga
# cargo-auditable                          orbiton
# cargo-binstall                           orcania
# cargo-binutils                           ord
# cargo-deps                               pgrok
# cargo-docset                             pixi
# cargo-generate                           plog
# cbonsai                                  pocketbase
# cdi                                      pop
# cdxgen                                   postgresql@16
# chaoskube                                powerlevel10k
# charls                                   prettierd
# checkdmarc                               procps@3
# clive                                    protobuf@21
# cloud-sql-proxy                          proxify
# cloudfox                                 proxygen
# cloudlist                                pwned
# codelimit                                pylyzer
# coder                                    pypy3.10
# colmap                                   pypy3.9
# conda-lock                               pyspelling
# convco                                   pystring
# core-lightning                           python-certifi
# couchbase-shell                          python-click
# counts                                   python-cryptography
# cppinsights                              python-flit-core
# crabz                                    python-lxml
# cryptopp                                 python-markupsafe
# crystalline                              python-mutagen
# ctpv                                     python-packaging
# cyclonedx-gomod                          python-pycurl
# cyclonedx-python                         python-pyparsing
# cycode                                   python-pyproject-hooks
# czkawka                                  python-pytz
# ddns-go                                  python-toml
# debugbreak                               qalculate-qt
# dnsrobocert                              quantum++
# dolphie                                  quictls
# dovi_tool                                recoverpy
# driftwood                                rio
# dysk                                     riscv64-elf-binutils
# dzr                                      riscv64-elf-gcc
# ebook2cw                                 riscv64-elf-gdb
# erg                                      risor
# erlang@25                                roadrunner
# espflash                                 roblox-ts
# eza                                      rojo
# falco                                    rpmspectool
# falcoctl                                 ruff-lsp
# fastgron                                 runme
# feishu2md                                rye
# fuc                                      s3scanner
# fw                                       sbom-tool
# fwupd                                    scrapy
# getmail6                                 sh4d0wup
# gffread                                  shodan
# ggshield                                 shub
# gickup                                   shuffledns
# gismo                                    shush
# git-credential-oauth                     sickchill
# git-tools                                slsa-verifier
# gitea                                    solr@8.11
# go@1.20                                  spacer
# goread                                   spotify_player
# gotestsum                                sqlpage
# gotestwaf                                sqlsmith
# govulncheck                              squiid
# grpc@1.54                                ssocr
# grype                                    staq
# helidon                                  strip-nondeterminism
# hex                                      surelog
# hivex                                    svlint
# hoverfly                                 svls
# hyfetch                                  swift-outdated
# img2pdf                                  tailwindcss
# imgdiet                                  tailwindcss-language-server
# imgdiff                                  talhelper
# iocextract                               tern
# ittapi                                   terraform-graph-beautifier
# jet                                      terragrunt-atlantis-config
# joshuto                                  tf-profile
# jr                                       toxiproxy
# jsign                                    tpm
# jsmn                                     trufflehog
# json2ts                                  trzsz-ssh
# judy                                     typical
# katana                                   tzdiff
# killport                                 udp2raw-multiplatform
# kor                                      uffizzi
# kosli-cli                                uhdm
# ldeep                                    uncover
# ldid-procursus                           urlfinder
# legitify                                 virtualfish
# libabigail                               votca
# libclc                                   vulkan-utility-libraries
# libdivsufsort                            vunnel
# libecpint                                wally
# libfastjson                              web-ext
# libgit2@1.6                              webpod
# libimobiledevice-glue                    wget2
# libint                                   woodpecker-cli
# libjcat                                  woof-doom
# libmapper                                wpscan
# libmediainfo                             wtfis
# libomemo-c                               wzprof
# libpaho-mqtt                             xbyak
# libpanel                                 xe
# libshumate                               xlsxio
# libversion                               yamlfmt
# libxmlb                                  yazi
# libzen                                   yder
# llm                                      yyjson
# llvm@16                                  zchunk
# lowdown                                  zrok
# lpeg
#
# You have 13 outdated formulae installed.
#
# ==> Tapping homebrew/cask
# Cloning into '/opt/homebrew/Library/Taps/homebrew/homebrew-cask'...
# remote: Enumerating objects: 798376, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# Receiving objects:   3% (28659/798376), 15.54 MiB | 1.81 MiB/s

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)


# Create a WebDriver instance (in this example, we use Chrome)
driver = webdriver.Chrome()

# Open a website
driver.get("https://www.latlong.net/convert-address-to-lat-long.html")
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# /var/folders/j0/w6j4gtqn3qgbyxvxzx172r_m0000gn/T/ipykernel_53269/3739653552.py in <module>
#       4 service = Service()
#       5 options = webdriver.ChromeOptions()
# ----> 6 driver = webdriver.Chrome(service=service, options=options)
#       7
#       8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      78             service = Service(executable_path, port, service_args, service_log_path)
#      79
# ---> 80         super().__init__(
#      81             DesiredCapabilities.CHROME["browserName"],
#      82             "goog",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     102
#     103         try:
# --> 104             super().__init__(
#     105                 command_executor=ChromiumRemoteConnection(
#     106                     remote_server_addr=self.service.service_url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284         self._authenticator_id = None
#     285         self.start_client()
# --> 286         self.start_session(capabilities, browser_profile)
#     287
#     288     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     376         w3c_caps = _make_w3c_caps(capabilities)
#     377         parameters = {"capabilities": w3c_caps}
# --> 378         response = self.execute(Command.NEW_SESSION, parameters)
#     379         if "sessionId" not in response:
#     380             response = response["value"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 117.0.5938.92 with binary path /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# Stacktrace:
# 0   chromedriver                        0x00000001013b56b8 chromedriver + 4937400
# 1   chromedriver                        0x00000001013acb73 chromedriver + 4901747
# 2   chromedriver                        0x0000000100f6a616 chromedriver + 435734
# 3   chromedriver                        0x0000000100f9cd10 chromedriver + 642320
# 4   chromedriver                        0x0000000100f9818a chromedriver + 622986
# 5   chromedriver                        0x0000000100f9467c chromedriver + 607868
# 6   chromedriver                        0x0000000100fdba08 chromedriver + 899592
# 7   chromedriver                        0x0000000100fdaebf chromedriver + 896703
# 8   chromedriver                        0x0000000100fd1de3 chromedriver + 859619
# 9   chromedriver                        0x0000000100f9fd7f chromedriver + 654719
# 10  chromedriver                        0x0000000100fa10de chromedriver + 659678
# 11  chromedriver                        0x00000001013712ad chromedriver + 4657837
# 12  chromedriver                        0x0000000101376130 chromedriver + 4677936
# 13  chromedriver                        0x000000010137cdef chromedriver + 4705775
# 14  chromedriver                        0x000000010137705a chromedriver + 4681818
# 15  chromedriver                        0x000000010134992c chromedriver + 4495660
# 16  chromedriver                        0x0000000101394838 chromedriver + 4802616
# 17  chromedriver                        0x00000001013949b7 chromedriver + 4802999
# 18  chromedriver                        0x00000001013a599f chromedriver + 4872607
# 19  libsystem_pthread.dylib             0x00007ff805b89514 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff805b8502f thread_start + 15
